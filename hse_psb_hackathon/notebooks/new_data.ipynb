# %%
import pandas as pd

data = pd.read_csv("hotels.csv", encoding="ISO-8859-1")

# %%
data.columns
# Out:
# Index(['countyCode', ' countyName', ' cityCode', ' cityName', ' HotelCode',
#        ' HotelName', ' HotelRating', ' Address', ' Attractions',
#        ' Description', ' FaxNumber', ' HotelFacilities', ' Map',
#        ' PhoneNumber', ' PinCode', ' HotelWebsiteUrl'],
#       dtype='object')

# %%
data[data[" countyName"] == "Russia"]
# Out:
#        countyCode  countyName   cityCode  cityName   HotelCode  \
# 608206         RU      Russia     100009    Abakan     1046551
# 608207         RU      Russia     100009    Abakan     1174056
# 608208         RU      Russia     100009    Abakan     1368768
# 608209         RU      Russia     100009    Abakan     1368906
# 608210         RU      Russia     100009    Abakan     1368973
# ...           ...         ...        ...       ...         ...
# 614079         RU      Russia     107929  Zlatoust     1878051
# 614080         RU      Russia     107929  Zlatoust     1879729
# 614081         RU      Russia     107929  Zlatoust     1942324
# 614082         RU      Russia     107929  Zlatoust     5002392
# 614083         RU      Russia     107929  Zlatoust     5002746
#
#                               HotelName  HotelRating  \
# 608206                     Abakan Hotel     FourStar
# 608207                    Hotel Druzhba    ThreeStar
# ...
